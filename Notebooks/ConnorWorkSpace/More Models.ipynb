# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, plot_confusion_matrix, confusion_matrix, plot_roc_curve, precision_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
import xgboost as xgb
import warnings
import seaborn as sn
pd.set_option('display.max_columns', None)

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../../data/UsableData.csv")
holdoutdf = pd.read_csv("../../data/UntestableData.csv")
df = df.drop(columns=['Unnamed: 0'])
df['HvarType'] = df['HvarType'].mask(df['HvarType'] != 'C', other='V')

df = df.drop(columns=['Catalog', 'VarFlag', '---', 'Period', 'moreVar', 'morePhoto', 'Source'])
holdoutdf = holdoutdf.drop(columns=['Unnamed: 0', 'Catalog', 'VarFlag', '---', 'Period', 'moreVar', 'morePhoto', 'Source'])

mask = {
    'C': 0,
    'V': 1
}
df['Target'] = df['HvarType'].map(mask)
# df['AstroRefIndicator'] = df['AstroRef'].isna()
# mask = {
#     True: 1,
#     False: 0
# }
# df['AstroRefIndicator'] = df['AstroRefIndicator'].map(mask)

x = df.drop(columns=['HvarType','Target','HIP'])
y = df['Target']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25, random_state=42)

# %%
def displayMetrics(fitModel, xtr, xte, ytr, yte):
    train_preds = fitModel.predict(xtr)
    test_preds = fitModel.predict(xte)
    train_probs = fitModel.predict_proba(xtr)[:,1]
    test_probs = fitModel.predict_proba(xte)[:,1]

    train_accuracy = accuracy_score(ytr, train_preds)
    test_accuracy = accuracy_score(yte, test_preds)
    train_recall = recall_score(ytr, train_preds, zero_division=0)
    test_recall = recall_score(yte, test_preds, zero_division=0)
    train_precision = precision_score(ytr, train_preds, zero_division=0)
    test_precision = precision_score(yte, test_preds, zero_division=0)
    train_f1 = f1_score(ytr, train_preds, zero_division=0)
    test_f1 = f1_score(yte, test_preds, zero_division=0)
    train_rocauc = roc_auc_score(ytr, train_probs)
    test_rocauc = roc_auc_score(yte, test_probs)

    print(F'\nTrain Accuracy:\t\t{train_accuracy}')
    print(F'Test Accuracy:\t\t{test_accuracy}')
    print(F"\nTrain Recall:\t\t{train_recall}")
    print(F'Test Recall:\t\t{test_recall}')
    print(F"\nTrain Precision:\t{train_precision}")
    print(F'Test Precision:\t\t{test_precision}')
    print(F"\nTrain f1:\t\t{train_f1}")
    print(F'Test f1:\t\t{test_f1}')
    print(F"\nTrain ROC-AUC:\t\t{train_rocauc}")
    print(F'Test ROC-AUC:\t\t{test_rocauc}')
    
    plot_confusion_matrix(fitModel, xte, yte)

# %%
numCols = [col for col in df.columns if df[col].dtype != 'O']
objCols = [col for col in df.columns if df[col].dtype == 'O']

# %%
# fun = []
# fun = numCols

# %%
# fun.remove("RAdeg")
# fun.remove("HD")

# %%
# fun.remove("BTmag")

# %%
# fun.remove("VTmag")

# %%
# fun.remove("e_VTmag")

# %%
# fun.remove("Hpmag")

# %%
# fun.remove("Hpmax")

# %%
# fun.remove("HPmin")

# %%
# fun.remove("e_DEdeg")

# %%
# fun.remove("e_pmDE")

# %%
# fun.remove("e_pmRA")

# %%
# fun.remove("pmDE:pmRA")

# %%
# fun.remove("pmDE:RA")

# %%
# fun.remove("(V-I)red")

# %%
# fun.remove("V-I")

# %%
# fun.remove("Hpscat")

# %%
# fun.remove("Ncomp")

# %%
# df[fun].corr()
# Out:
#                 HIP      Vmag     RAdeg     DEdeg       Plx      pmRA  \
# HIP        1.000000  0.005603  0.999867 -0.014275 -0.001337 -0.028091
# Vmag       0.005603  1.000000  0.005074 -0.006714 -0.076837  0.000787
# RAdeg      0.999867  0.005074  1.000000 -0.014474 -0.001299 -0.028862
# DEdeg     -0.014275 -0.006714 -0.014474  1.000000 -0.007203  0.006984
# Plx       -0.001337 -0.076837 -0.001299 -0.007203  1.000000 -0.035570
# pmRA      -0.028091  0.000787 -0.028862  0.006984 -0.035570  1.000000
# pmDE      -0.009449 -0.036742 -0.009414 -0.011244 -0.229038 -0.052740
# e_RAdeg    0.006865  0.197477  0.006954 -0.012804  0.085810  0.005190
# e_DEdeg    0.006921  0.198944  0.006961 -0.016224  0.082538  0.003574
# e_Plx      0.003868  0.302839  0.003973 -0.016633  0.121926  0.011809
# e_pmRA     0.008539  0.252194  0.008592 -0.015155  0.118566  0.004464
# e_pmDE     0.001978  0.268502  0.002126 -0.018135  0.118937  0.004450
# DE:RA      0.020286  0.002481  0.019341 -0.020387  0.006584  0.093028
# Plx:RA    -0.499665 -0.026535 -0.499887  0.274880 -0.016958  0.052483
# Plx:DE     0.051221 -0.018517  0.050313 -0.039435 -0.024114 -0.005985
# pmRA:RA    0.083660 -0.040343  0.084921 -0.011347 -0.013747 -0.017664
# pmRA:DE    0.050860 -0.007377  0.050449  0.037640 -0.004115  0.018266
# pmRA:Plx   0.042807  0.008040  0.042106 -0.062354  0.007648  0.054382
# pmDE:RA    0.070914 -0.005967  0.070176  0.055442 -0.005188  0.023102
# pmDE:DE    0.025945 -0.019249  0.027313  0.009235  0.001706 -0.009652
# pmDE:Plx   0.079432 -0.010638  0.077654  0.053619 -0.014590  0.005030
# pmDE:pmRA -0.055308  0.001178 -0.055905  0.040145  0.003736  0.087166
# F1        -0.003102  0.017501 -0.003021 -0.008704  0.065030 -0.004160
# F2        -0.015720  0.022283 -0.015525  0.009211  0.031809 -0.004206
# BTmag      0.013923  0.885359  0.013672 -0.008348 -0.138464 -0.005161
# e_BTmag    0.017451  0.513846  0.017524  0.007690  0.011398 -0.007273
# VTmag      0.005711  0.996395  0.005533 -0.004245 -0.140990 -0.008271
# e_VTmag    0.008180  0.704777  0.008312  0.003405 -0.018317 -0.006535
# B-V        0.024390  0.078055  0.024061 -0.009318  0.015849  0.005965
# e_B-V      0.011522  0.214042  0.012100  0.014375 -0.041107  0.001009
# V-I        0.026753  0.086106  0.026416 -0.005959  0.034465  0.004355
# e_V-I      0.013885  0.242594  0.013899  0.029969 -0.026624 -0.002492
# Hpmag      0.005427  0.997618  0.004942 -0.007505 -0.072840  0.001118
# e_Hpmag    0.010639  0.191309  0.010572 -0.010118  0.027667  0.002375
# Hpscat     0.013848  0.181560  0.013854 -0.004455 -0.052869 -0.000033
# o_Hpmag    0.040626 -0.053876  0.039571 -0.016047 -0.028384  0.001469
# Hpmax      0.003434  0.992203  0.003063 -0.005360 -0.076788 -0.002240
# HPmin      0.006048  0.994848  0.005510 -0.005663 -0.082672 -0.001888
# Nsys       0.001649  0.173799  0.000754  0.040002  0.069408 -0.039176
# Ncomp      0.004370 -0.052645  0.004397 -0.008080  0.031163  0.002778
# theta     -0.005534 -0.009034 -0.005582  0.009668  0.033456 -0.016377
# rho        0.023507  0.021242  0.023437 -0.017719  0.031817 -0.000114
# e_rho     -0.005192  0.234420 -0.005092 -0.005409 -0.010440  0.005728
# dHp       -0.001144 -0.133417 -0.001151  0.015768 -0.036962  0.011538
# e_dHp     -0.014720  0.146736 -0.014671  0.013637 -0.053929 -0.005189
# HD         0.858588  0.115833  0.858687  0.042362 -0.009221 -0.000809
# (V-I)red   0.027701  0.082092  0.027448 -0.001573  0.044271  0.003518
# Target     0.015230 -0.066025  0.015191 -0.012115  0.000448 -0.002769
#
#                pmDE   e_RAdeg   e_DEdeg     e_Plx    e_pmRA    e_pmDE  \
# HIP       -0.009449  0.006865  0.006921  0.003868  0.008539  0.001978
# Vmag      -0.036742  0.197477  0.198944  0.302839  0.252194  0.268502
# RAdeg     -0.009414  0.006954  0.006961  0.003973  0.008592  0.002126
# DEdeg     -0.011244 -0.012804 -0.016224 -0.016633 -0.015155 -0.018135
# Plx       -0.229038  0.085810  0.082538  0.121926  0.118566  0.118937
# pmRA      -0.052740  0.005190  0.003574  0.011809  0.004464  0.004450
# pmDE       1.000000  0.014549  0.018125  0.000602 -0.001800  0.007854
# e_RAdeg    0.014549  1.000000  0.956556  0.644871  0.727361  0.705992
# e_DEdeg    0.018125  0.956556  1.000000  0.636983  0.674326  0.707114
# e_Plx      0.000602  0.644871  0.636983  1.000000  0.833790  0.867618
# e_pmRA    -0.001800  0.727361  0.674326  0.833790  1.000000  0.942000
# e_pmDE     0.007854  0.705992  0.707114  0.867618  0.942000  1.000000
# DE:RA     -0.003750  0.002019  0.000946  0.009082  0.012546  0.011379
# Plx:RA     0.006033 -0.007308 -0.011026 -0.013477 -0.011054 -0.017496
# Plx:DE     0.043334  0.007294  0.014721 -0.032136 -0.025865 -0.011044
# pmRA:RA    0.007203 -0.024354 -0.020982 -0.038904 -0.033270 -0.029975
# pmRA:DE    0.008727 -0.005258 -0.004295 -0.008418 -0.008629 -0.006837
# pmRA:Plx  -0.011292  0.000518 -0.000716  0.001709  0.005930  0.003445
# pmDE:RA    0.007562 -0.007871 -0.005013 -0.014491 -0.013281 -0.009413
# pmDE:DE    0.001426 -0.011045 -0.012240 -0.026862 -0.024596 -0.017478
# pmDE:Plx   0.006941  0.000668  0.001125 -0.000224 -0.000318 -0.006105
# pmDE:pmRA -0.007498  0.008691  0.005599  0.011497  0.014051  0.011672
# F1        -0.007070  0.175326  0.172912  0.196979  0.212806  0.218038
# F2        -0.012132  0.088454  0.090526  0.103821  0.107269  0.113297
# BTmag     -0.021979  0.141483  0.140483  0.240111  0.204738  0.206678
# e_BTmag   -0.040457  0.177911  0.169514  0.249984  0.233614  0.222726
# VTmag     -0.013146  0.171560  0.170477  0.280865  0.240376  0.243665
# e_VTmag   -0.045528  0.274465  0.261623  0.370201  0.349868  0.333943
# B-V       -0.044090  0.000956 -0.000828  0.026379  0.019452  0.017028
# e_B-V      0.013796  0.095318  0.094352  0.154912  0.125035  0.130829
# V-I       -0.048293  0.005908  0.002941  0.037961  0.027044  0.025092
# e_V-I      0.005163  0.091494  0.086791  0.153882  0.123565  0.128567
# Hpmag     -0.038832  0.191743  0.193134  0.299991  0.249799  0.265179
# e_Hpmag    0.030946  0.687127  0.699821  0.482263  0.477984  0.502996
# Hpscat     0.009532  0.141807  0.137852  0.176207  0.146281  0.164427
# o_Hpmag    0.061282 -0.104973 -0.034333 -0.096487 -0.170125 -0.085735
# Hpmax     -0.045085  0.181119  0.181676  0.354045  0.270466  0.309649
# HPmin     -0.042726  0.202796  0.203030  0.375908  0.289780  0.331528
# Nsys       0.019363  0.322105  0.325506  0.303582  0.313574  0.339642
# Ncomp      0.006599  0.036536  0.039439  0.070796  0.047477  0.055483
# theta      0.006081 -0.002833 -0.006210  0.000981 -0.002593 -0.001900
# rho       -0.009875 -0.057801 -0.058527  0.069392  0.036908  0.040079
# e_rho     -0.019426  0.136553  0.128155  0.105163  0.096440  0.075594
# dHp        0.029597 -0.244403 -0.242524 -0.278460 -0.256878 -0.264282
# e_dHp      0.006856  0.028315  0.032453 -0.081530 -0.068543 -0.074466
# HD        -0.028386  0.036904  0.027367  0.067859  0.064783  0.041896
# (V-I)red  -0.048470  0.005549  0.004001  0.032208  0.022749  0.022742
# Target     0.020604  0.151275  0.156936  0.181985  0.161457  0.183398
#
#               DE:RA    Plx:RA    Plx:DE   pmRA:RA   pmRA:DE  pmRA:Plx  \
# HIP        0.020286 -0.499665  0.051221  0.083660  0.050860  0.042807
# Vmag       0.002481 -0.026535 -0.018517 -0.040343 -0.007377  0.008040
# RAdeg      0.019341 -0.499887  0.050313  0.084921  0.050449  0.042106
# DEdeg     -0.020387  0.274880 -0.039435 -0.011347  0.037640 -0.062354
# Plx        0.006584 -0.016958 -0.024114 -0.013747 -0.004115  0.007648
# pmRA       0.093028  0.052483 -0.005985 -0.017664  0.018266  0.054382
# pmDE      -0.003750  0.006033  0.043334  0.007203  0.008727 -0.011292
# e_RAdeg    0.002019 -0.007308  0.007294 -0.024354 -0.005258  0.000518
# e_DEdeg    0.000946 -0.011026  0.014721 -0.020982 -0.004295 -0.000716
# e_Plx      0.009082 -0.013477 -0.032136 -0.038904 -0.008418  0.001709
# e_pmRA     0.012546 -0.011054 -0.025865 -0.033270 -0.008629  0.005930
# e_pmDE     0.011379 -0.017496 -0.011044 -0.029975 -0.006837  0.003445
# DE:RA      1.000000 -0.046865  0.007160 -0.010566 -0.016748  0.217957
# Plx:RA    -0.046865  1.000000 -0.041968 -0.111549  0.035440 -0.128048
# Plx:DE     0.007160 -0.041968  1.000000  0.089312  0.029457 -0.009150
# pmRA:RA   -0.010566 -0.111549  0.089312  1.000000  0.026264  0.037413
# pmRA:DE   -0.016748  0.035440  0.029457  0.026264  1.000000 -0.255042
# pmRA:Plx   0.217957 -0.128048 -0.009150  0.037413 -0.255042  1.000000
# pmDE:RA   -0.008004  0.040361  0.033080  0.037568  0.892142 -0.107790
# pmDE:DE   -0.010936 -0.065048  0.043941  0.447575  0.046616  0.010423
# pmDE:Plx   0.016719 -0.020187 -0.079704 -0.102333 -0.000947  0.030874
# pmDE:pmRA  0.764343  0.096153 -0.008324 -0.024705  0.043000  0.200966
# F1         0.004701 -0.003490  0.034910 -0.029174 -0.005219 -0.009825
# F2        -0.003916  0.008079 -0.017260 -0.013358 -0.000431 -0.016841
# BTmag     -0.000435 -0.045016 -0.037776 -0.033271 -0.001331  0.011063
# e_BTmag    0.002466 -0.029473 -0.051452 -0.026571 -0.001300  0.005719
# VTmag     -0.000534 -0.028546 -0.026044 -0.028835 -0.004535  0.007009
# e_VTmag    0.002307 -0.025157 -0.074301 -0.028854 -0.011863  0.008409
# B-V        0.001652 -0.050460 -0.035712 -0.024892  0.006968  0.016013
# e_B-V      0.002102 -0.010957  0.002630 -0.019480  0.006340  0.000133
# V-I        0.000406 -0.048262 -0.023291 -0.024518  0.007171  0.014822
# e_V-I     -0.001325 -0.005430  0.001575 -0.023896  0.010373 -0.000020
# Hpmag      0.002532 -0.028150 -0.022042 -0.040779 -0.007333  0.008843
# e_Hpmag   -0.000475 -0.008904  0.024130 -0.022152  0.000572 -0.003132
# Hpscat    -0.002262 -0.014314  0.029843 -0.028632  0.010701 -0.001366
# o_Hpmag   -0.022756 -0.044510  0.314440  0.025782  0.023593 -0.020189
# Hpmax      0.001971 -0.026913 -0.029245 -0.038498 -0.007824  0.010452
# HPmin      0.001565 -0.028668 -0.023497 -0.042452 -0.005850  0.009857
# Nsys       0.023302  0.002897  0.000216 -0.016151  0.000702 -0.008195
# Ncomp     -0.008950 -0.004962  0.058908 -0.008632 -0.003221 -0.006635
# theta     -0.068722  0.000916 -0.001981 -0.000014  0.004621  0.000388
# rho        0.003211 -0.023458  0.005675 -0.000918  0.015459 -0.006858
# e_rho      0.007344  0.000109 -0.040239 -0.014207 -0.004819  0.005182
# dHp        0.007939  0.027610 -0.015186  0.015734  0.013660  0.006509
# e_dHp      0.020921  0.006003 -0.018438  0.013781 -0.014866  0.023666
# HD         0.048859 -0.406535  0.043278  0.076926  0.049487  0.057881
# (V-I)red   0.000310 -0.047622 -0.022264 -0.025953  0.006653  0.012969
# Target    -0.006691 -0.018114  0.071036 -0.005264  0.006655 -0.008474
#
#             pmDE:RA   pmDE:DE  pmDE:Plx  pmDE:pmRA        F1        F2  \
# HIP        0.070914  0.025945  0.079432  -0.055308 -0.003102 -0.015720
# Vmag      -0.005967 -0.019249 -0.010638   0.001178  0.017501  0.022283
# RAdeg      0.070176  0.027313  0.077654  -0.055905 -0.003021 -0.015525
# DEdeg      0.055442  0.009235  0.053619   0.040145 -0.008704  0.009211
# Plx       -0.005188  0.001706 -0.014590   0.003736  0.065030  0.031809
# pmRA       0.023102 -0.009652  0.005030   0.087166 -0.004160 -0.004206
# pmDE       0.007562  0.001426  0.006941  -0.007498 -0.007070 -0.012132
# e_RAdeg   -0.007871 -0.011045  0.000668   0.008691  0.175326  0.088454
# e_DEdeg   -0.005013 -0.012240  0.001125   0.005599  0.172912  0.090526
# e_Plx     -0.014491 -0.026862 -0.000224   0.011497  0.196979  0.103821
# e_pmRA    -0.013281 -0.024596 -0.000318   0.014051  0.212806  0.107269
# e_pmDE    -0.009413 -0.017478 -0.006105   0.011672  0.218038  0.113297
# DE:RA     -0.008004 -0.010936  0.016719   0.764343  0.004701 -0.003916
# Plx:RA     0.040361 -0.065048 -0.020187   0.096153 -0.003490  0.008079
# Plx:DE     0.033080  0.043941 -0.079704  -0.008324  0.034910 -0.017260
# pmRA:RA    0.037568  0.447575 -0.102333  -0.024705 -0.029174 -0.013358
# pmRA:DE    0.892142  0.046616 -0.000947   0.043000 -0.005219 -0.000431
# pmRA:Plx  -0.107790  0.010423  0.030874   0.200966 -0.009825 -0.016841
# pmDE:RA    1.000000  0.035543  0.023847   0.090208 -0.006960 -0.004357
# pmDE:DE    0.035543  1.000000 -0.492690  -0.008088 -0.014002  0.006831
# pmDE:Plx   0.023847 -0.492690  1.000000   0.005181 -0.014367 -0.011023
# pmDE:pmRA  0.090208 -0.008088  0.005181   1.000000  0.005853  0.002988
# F1        -0.006960 -0.014002 -0.014367   0.005853  1.000000  0.239395
# F2        -0.004357  0.006831 -0.011023   0.002988  0.239395  1.000000
# BTmag      0.001704 -0.011455 -0.006392  -0.007332 -0.035999  0.013812
# e_BTmag   -0.002952 -0.007746 -0.018286  -0.005534  0.031962  0.047016
# VTmag     -0.002428 -0.009413 -0.011778  -0.003483 -0.008947  0.011922
# e_VTmag   -0.016266 -0.005946 -0.023013  -0.001027  0.063574  0.047250
# B-V        0.009182 -0.011626  0.009336  -0.009479 -0.058971  0.010851
# e_B-V      0.003131 -0.007452 -0.006268  -0.002375  0.074488  0.039224
# V-I        0.010646 -0.010284  0.006096  -0.008199 -0.046221  0.021405
# e_V-I      0.009536 -0.018370 -0.003581  -0.005687  0.042337  0.041858
# Hpmag     -0.006057 -0.018880 -0.010246   0.000956  0.015767  0.020806
# e_Hpmag    0.000108 -0.015761 -0.004450   0.001778  0.139951  0.078988
# Hpscat     0.013048 -0.023251 -0.006013  -0.000738  0.093632  0.059308
# o_Hpmag    0.038103 -0.005299 -0.005172  -0.029640  0.006798 -0.036271
# Hpmax     -0.006534 -0.017236 -0.010161   0.000224 -0.020160  0.002240
# HPmin     -0.004147 -0.021019 -0.010677  -0.000006 -0.001382  0.012957
# Nsys      -0.002029 -0.007795  0.009583   0.030075  0.287005  0.194895
# Ncomp     -0.004826  0.000755 -0.014607  -0.008020  0.199730  0.068235
# theta      0.005239  0.015010 -0.013861  -0.034376 -0.009600 -0.004020
# rho        0.008156 -0.016333 -0.005522   0.006044  0.209956  0.229496
# e_rho     -0.004141 -0.022629  0.009245   0.016131 -0.006900  0.024958
# dHp        0.007810  0.003417  0.003024   0.017534 -0.071867 -0.125807
# e_dHp     -0.003801 -0.001633  0.012205   0.026904 -0.096932  0.014607
# HD         0.063715  0.030471  0.064042  -0.017284  0.000545 -0.013797
# (V-I)red   0.009484 -0.011377  0.003325  -0.007755 -0.040959  0.024025
# Target     0.004369 -0.003952 -0.014243  -0.010082  0.241847  0.104271
#
#               BTmag   e_BTmag     VTmag   e_VTmag       B-V     e_B-V  \
# HIP        0.013923  0.017451  0.005711  0.008180  0.024390  0.011522
# Vmag       0.885359  0.513846  0.996395  0.704777  0.078055  0.214042
# RAdeg      0.013672  0.017524  0.005533  0.008312  0.024061  0.012100
# DEdeg     -0.008348  0.007690 -0.004245  0.003405 -0.009318  0.014375
# Plx       -0.138464  0.011398 -0.140990 -0.018317  0.015849 -0.041107
# pmRA      -0.005161 -0.007273 -0.008271 -0.006535  0.005965  0.001009
# pmDE      -0.021979 -0.040457 -0.013146 -0.045528 -0.044090  0.013796
# e_RAdeg    0.141483  0.177911  0.171560  0.274465  0.000956  0.095318
# e_DEdeg    0.140483  0.169514  0.170477  0.261623 -0.000828  0.094352
# e_Plx      0.240111  0.249984  0.280865  0.370201  0.026379  0.154912
# e_pmRA     0.204738  0.233614  0.240376  0.349868  0.019452  0.125035
# e_pmDE     0.206678  0.222726  0.243665  0.333943  0.017028  0.130829
# DE:RA     -0.000435  0.002466 -0.000534  0.002307  0.001652  0.002102
# Plx:RA    -0.045016 -0.029473 -0.028546 -0.025157 -0.050460 -0.010957
# Plx:DE    -0.037776 -0.051452 -0.026044 -0.074301 -0.035712  0.002630
# pmRA:RA   -0.033271 -0.026571 -0.028835 -0.028854 -0.024892 -0.019480
# pmRA:DE   -0.001331 -0.001300 -0.004535 -0.011863  0.006968  0.006340
# pmRA:Plx   0.011063  0.005719  0.007009  0.008409  0.016013  0.000133
# pmDE:RA    0.001704 -0.002952 -0.002428 -0.016266  0.009182  0.003131
# pmDE:DE   -0.011455 -0.007746 -0.009413 -0.005946 -0.011626 -0.007452
# pmDE:Plx  -0.006392 -0.018286 -0.011778 -0.023013  0.009336 -0.006268
# pmDE:pmRA -0.007332 -0.005534 -0.003483 -0.001027 -0.009479 -0.002375
# F1        -0.035999  0.031962 -0.008947  0.063574 -0.058971  0.074488
# F2         0.013812  0.047016  0.011922  0.047250  0.010851  0.039224
# BTmag      1.000000  0.625563  0.908117  0.628572  0.493907  0.229663
# e_BTmag    0.625563  1.000000  0.531872  0.711205  0.364174  0.314687
# VTmag      0.908117  0.531872  1.000000  0.706535  0.090433  0.209053
# e_VTmag    0.628572  0.711205  0.706535  1.000000  0.038008  0.238013
# B-V        0.493907  0.364174  0.090433  0.038008  1.000000  0.129206
# e_B-V      0.229663  0.314687  0.209053  0.238013  0.129206  1.000000
# V-I        0.454662  0.348810  0.084372  0.054598  0.906788  0.158192
# e_V-I      0.328220  0.504297  0.240856  0.320583  0.267406  0.474248
# Hpmag      0.893344  0.511320  0.995901  0.700481  0.096474  0.206545
# e_Hpmag    0.140147  0.204097  0.128407  0.226894  0.090462  0.212678
# Hpscat     0.163768  0.220650  0.127778  0.188747  0.145917  0.273026
# o_Hpmag   -0.055624 -0.147559 -0.051423 -0.213429 -0.033721 -0.038210
# Hpmax      0.886304  0.491953  0.992809  0.689376  0.086627  0.180418
# HPmin      0.894280  0.515784  0.994244  0.706107  0.108120  0.221663
# Nsys       0.110217  0.109072  0.122195  0.174514  0.004153 -0.042812
# Ncomp     -0.099221 -0.036599 -0.048203 -0.009832 -0.136462  0.243615
# theta      0.006816  0.010550 -0.002856  0.000448  0.027369 -0.021516
# rho        0.003337 -0.002748  0.011389  0.039996 -0.004793  0.055571
# e_rho      0.241256  0.140884  0.218680  0.141698  0.153752  0.197541
# dHp       -0.096850 -0.128654 -0.120798 -0.176143  0.006021  0.223817
# e_dHp      0.186445  0.128541  0.144920  0.046842  0.141442  0.009985
# HD         0.116283  0.134831  0.114967  0.175369  0.041162  0.036142
# (V-I)red   0.428450  0.316818  0.082417  0.060377  0.859344  0.148748
# Target    -0.062715  0.055686 -0.104635  0.005032  0.074767  0.195160
#
#                 V-I     e_V-I     Hpmag   e_Hpmag    Hpscat   o_Hpmag  \
# HIP        0.026753  0.013885  0.005427  0.010639  0.013848  0.040626
# Vmag       0.086106  0.242594  0.997618  0.191309  0.181560 -0.053876
# RAdeg      0.026416  0.013899  0.004942  0.010572  0.013854  0.039571
# DEdeg     -0.005959  0.029969 -0.007505 -0.010118 -0.004455 -0.016047
# Plx        0.034465 -0.026624 -0.072840  0.027667 -0.052869 -0.028384
# pmRA       0.004355 -0.002492  0.001118  0.002375 -0.000033  0.001469
# pmDE      -0.048293  0.005163 -0.038832  0.030946  0.009532  0.061282
# e_RAdeg    0.005908  0.091494  0.191743  0.687127  0.141807 -0.104973
# e_DEdeg    0.002941  0.086791  0.193134  0.699821  0.137852 -0.034333
# e_Plx      0.037961  0.153882  0.299991  0.482263  0.176207 -0.096487
# e_pmRA     0.027044  0.123565  0.249799  0.477984  0.146281 -0.170125
# e_pmDE     0.025092  0.128567  0.265179  0.502996  0.164427 -0.085735
# DE:RA      0.000406 -0.001325  0.002532 -0.000475 -0.002262 -0.022756
# Plx:RA    -0.048262 -0.005430 -0.028150 -0.008904 -0.014314 -0.044510
# Plx:DE    -0.023291  0.001575 -0.022042  0.024130  0.029843  0.314440
# pmRA:RA   -0.024518 -0.023896 -0.040779 -0.022152 -0.028632  0.025782
# pmRA:DE    0.007171  0.010373 -0.007333  0.000572  0.010701  0.023593
# pmRA:Plx   0.014822 -0.000020  0.008843 -0.003132 -0.001366 -0.020189
# pmDE:RA    0.010646  0.009536 -0.006057  0.000108  0.013048  0.038103
# pmDE:DE   -0.010284 -0.018370 -0.018880 -0.015761 -0.023251 -0.005299
# pmDE:Plx   0.006096 -0.003581 -0.010246 -0.004450 -0.006013 -0.005172
# pmDE:pmRA -0.008199 -0.005687  0.000956  0.001778 -0.000738 -0.029640
# F1        -0.046221  0.042337  0.015767  0.139951  0.093632  0.006798
# F2         0.021405  0.041858  0.020806  0.078988  0.059308 -0.036271
# BTmag      0.454662  0.328220  0.893344  0.140147  0.163768 -0.055624
# e_BTmag    0.348810  0.504297  0.511320  0.204097  0.220650 -0.147559
# VTmag      0.084372  0.240856  0.995901  0.128407  0.127778 -0.051423
# e_VTmag    0.054598  0.320583  0.700481  0.226894  0.188747 -0.213429
# B-V        0.906788  0.267406  0.096474  0.090462  0.145917 -0.033721
# e_B-V      0.158192  0.474248  0.206545  0.212678  0.273026 -0.038210
# V-I        1.000000  0.398785  0.083882  0.190493  0.293561 -0.026602
# e_V-I      0.398785  1.000000  0.223060  0.419251  0.551279 -0.053358
# Hpmag      0.083882  0.223060  1.000000  0.178684  0.164634 -0.056213
# e_Hpmag    0.190493  0.419251  0.178684  1.000000  0.893969 -0.039802
# Hpscat     0.293561  0.551279  0.164634  0.893969  1.000000  0.008311
# o_Hpmag   -0.026602 -0.053358 -0.056213 -0.039802  0.008311  1.000000
# Hpmax      0.061414  0.175471  0.995879  0.064632  0.083169 -0.058046
# HPmin      0.108510  0.261676  0.995367  0.211189  0.248381 -0.054171
# Nsys       0.003470  0.070768  0.168197  0.357563  0.231618  0.001128
# Ncomp     -0.125964 -0.009475 -0.054033 -0.040300 -0.035925  0.067899
# theta      0.032453  0.005487 -0.006945 -0.001625 -0.010519 -0.007064
# rho       -0.015724  0.017293  0.020579  0.335380  0.091352  0.022320
# e_rho      0.142984  0.153707  0.235379  0.189251  0.132697 -0.077189
# dHp       -0.028900 -0.018304 -0.132674 -0.037123 -0.087324  0.033380
# e_dHp      0.151896  0.122122  0.147129  0.096931  0.104726 -0.048227
# HD         0.042091  0.054067  0.115742  0.024189  0.028904  0.017097
# (V-I)red   0.958993  0.381833  0.078364  0.172171  0.306300 -0.022918
# Target     0.161360  0.153907 -0.078451  0.196855  0.215800  0.126039
#
#               Hpmax     HPmin      Nsys     Ncomp     theta       rho  \
# HIP        0.003434  0.006048  0.001649  0.004370 -0.005534  0.023507
# Vmag       0.992203  0.994848  0.173799 -0.052645 -0.009034  0.021242
# RAdeg      0.003063  0.005510  0.000754  0.004397 -0.005582  0.023437
# DEdeg     -0.005360 -0.005663  0.040002 -0.008080  0.009668 -0.017719
# Plx       -0.076788 -0.082672  0.069408  0.031163  0.033456  0.031817
# pmRA      -0.002240 -0.001888 -0.039176  0.002778 -0.016377 -0.000114
# pmDE      -0.045085 -0.042726  0.019363  0.006599  0.006081 -0.009875
# e_RAdeg    0.181119  0.202796  0.322105  0.036536 -0.002833 -0.057801
# e_DEdeg    0.181676  0.203030  0.325506  0.039439 -0.006210 -0.058527
# e_Plx      0.354045  0.375908  0.303582  0.070796  0.000981  0.069392
# e_pmRA     0.270466  0.289780  0.313574  0.047477 -0.002593  0.036908
# e_pmDE     0.309649  0.331528  0.339642  0.055483 -0.001900  0.040079
# DE:RA      0.001971  0.001565  0.023302 -0.008950 -0.068722  0.003211
# Plx:RA    -0.026913 -0.028668  0.002897 -0.004962  0.000916 -0.023458
# Plx:DE    -0.029245 -0.023497  0.000216  0.058908 -0.001981  0.005675
# pmRA:RA   -0.038498 -0.042452 -0.016151 -0.008632 -0.000014 -0.000918
# pmRA:DE   -0.007824 -0.005850  0.000702 -0.003221  0.004621  0.015459
# pmRA:Plx   0.010452  0.009857 -0.008195 -0.006635  0.000388 -0.006858
# pmDE:RA   -0.006534 -0.004147 -0.002029 -0.004826  0.005239  0.008156
# pmDE:DE   -0.017236 -0.021019 -0.007795  0.000755  0.015010 -0.016333
# pmDE:Plx  -0.010161 -0.010677  0.009583 -0.014607 -0.013861 -0.005522
# pmDE:pmRA  0.000224 -0.000006  0.030075 -0.008020 -0.034376  0.006044
# F1        -0.020160 -0.001382  0.287005  0.199730 -0.009600  0.209956
# F2         0.002240  0.012957  0.194895  0.068235 -0.004020  0.229496
# BTmag      0.886304  0.894280  0.110217 -0.099221  0.006816  0.003337
# e_BTmag    0.491953  0.515784  0.109072 -0.036599  0.010550 -0.002748
# VTmag      0.992809  0.994244  0.122195 -0.048203 -0.002856  0.011389
# e_VTmag    0.689376  0.706107  0.174514 -0.009832  0.000448  0.039996
# B-V        0.086627  0.108120  0.004153 -0.136462  0.027369 -0.004793
# e_B-V      0.180418  0.221663 -0.042812  0.243615 -0.021516  0.055571
# V-I        0.061414  0.108510  0.003470 -0.125964  0.032453 -0.015724
# e_V-I      0.175471  0.261676  0.070768 -0.009475  0.005487  0.017293
# Hpmag      0.995879  0.995367  0.168197 -0.054033 -0.006945  0.020579
# e_Hpmag    0.064632  0.211189  0.357563 -0.040300 -0.001625  0.335380
# Hpscat     0.083169  0.248381  0.231618 -0.035925 -0.010519  0.091352
# o_Hpmag   -0.058046 -0.054171  0.001128  0.067899 -0.007064  0.022320
# Hpmax      1.000000  0.985211  0.027151 -0.046465 -0.006795  0.018837
# HPmin      0.985211  1.000000  0.067806 -0.050400 -0.007540  0.025811
# Nsys       0.027151  0.067806  1.000000 -0.548875  0.004068 -0.005960
# Ncomp     -0.046465 -0.050400 -0.548875  1.000000       NaN       NaN
# theta     -0.006795 -0.007540  0.004068       NaN  1.000000  0.004481
# rho        0.018837  0.025811 -0.005960       NaN  0.004481  1.000000
# e_rho      0.232906  0.236198  0.025046       NaN  0.012224  0.127363
# dHp       -0.131161 -0.134717 -0.009720       NaN  0.001660  0.200040
# e_dHp      0.144968  0.147844 -0.000560       NaN  0.013365 -0.146768
# HD         0.113068  0.116429  0.016091 -0.004823  0.003024  0.023278
# (V-I)red   0.054438  0.105059  0.015401 -0.121697  0.031086  0.000064
# Target    -0.122106 -0.077085  0.104647  0.474274 -0.007712  0.023327
#
#               e_rho       dHp     e_dHp        HD  (V-I)red    Target
# HIP       -0.005192 -0.001144 -0.014720  0.858588  0.027701  0.015230
# Vmag       0.234420 -0.133417  0.146736  0.115833  0.082092 -0.066025
# RAdeg     -0.005092 -0.001151 -0.014671  0.858687  0.027448  0.015191
# DEdeg     -0.005409  0.015768  0.013637  0.042362 -0.001573 -0.012115
# Plx       -0.010440 -0.036962 -0.053929 -0.009221  0.044271  0.000448
# pmRA       0.005728  0.011538 -0.005189 -0.000809  0.003518 -0.002769
# pmDE      -0.019426  0.029597  0.006856 -0.028386 -0.048470  0.020604
# e_RAdeg    0.136553 -0.244403  0.028315  0.036904  0.005549  0.151275
# e_DEdeg    0.128155 -0.242524  0.032453  0.027367  0.004001  0.156936
# e_Plx      0.105163 -0.278460 -0.081530  0.067859  0.032208  0.181985
# e_pmRA     0.096440 -0.256878 -0.068543  0.064783  0.022749  0.161457
# e_pmDE     0.075594 -0.264282 -0.074466  0.041896  0.022742  0.183398
# DE:RA      0.007344  0.007939  0.020921  0.048859  0.000310 -0.006691
# Plx:RA     0.000109  0.027610  0.006003 -0.406535 -0.047622 -0.018114
# Plx:DE    -0.040239 -0.015186 -0.018438  0.043278 -0.022264  0.071036
# pmRA:RA   -0.014207  0.015734  0.013781  0.076926 -0.025953 -0.005264
# pmRA:DE   -0.004819  0.013660 -0.014866  0.049487  0.006653  0.006655
# pmRA:Plx   0.005182  0.006509  0.023666  0.057881  0.012969 -0.008474
# pmDE:RA   -0.004141  0.007810 -0.003801  0.063715  0.009484  0.004369
# pmDE:DE   -0.022629  0.003417 -0.001633  0.030471 -0.011377 -0.003952
# pmDE:Plx   0.009245  0.003024  0.012205  0.064042  0.003325 -0.014243
# pmDE:pmRA  0.016131  0.017534  0.026904 -0.017284 -0.007755 -0.010082
# F1        -0.006900 -0.071867 -0.096932  0.000545 -0.040959  0.241847
# F2         0.024958 -0.125807  0.014607 -0.013797  0.024025  0.104271
# BTmag      0.241256 -0.096850  0.186445  0.116283  0.428450 -0.062715
# e_BTmag    0.140884 -0.128654  0.128541  0.134831  0.316818  0.055686
# VTmag      0.218680 -0.120798  0.144920  0.114967  0.082417 -0.104635
# e_VTmag    0.141698 -0.176143  0.046842  0.175369  0.060377  0.005032
# B-V        0.153752  0.006021  0.141442  0.041162  0.859344  0.074767
# e_B-V      0.197541  0.223817  0.009985  0.036142  0.148748  0.195160
# V-I        0.142984 -0.028900  0.151896  0.042091  0.958993  0.161360
# e_V-I      0.153707 -0.018304  0.122122  0.054067  0.381833  0.153907
# Hpmag      0.235379 -0.132674  0.147129  0.115742  0.078364 -0.078451
# e_Hpmag    0.189251 -0.037123  0.096931  0.024189  0.172171  0.196855
# Hpscat     0.132697 -0.087324  0.104726  0.028904  0.306300  0.215800
# o_Hpmag   -0.077189  0.033380 -0.048227  0.017097 -0.022918  0.126039
# Hpmax      0.232906 -0.131161  0.144968  0.113068  0.054438 -0.122106
# HPmin      0.236198 -0.134717  0.147844  0.116429  0.105059 -0.077085
# Nsys       0.025046 -0.009720 -0.000560  0.016091  0.015401  0.104647
# Ncomp           NaN       NaN       NaN -0.004823 -0.121697  0.474274
# theta      0.012224  0.001660  0.013365  0.003024  0.031086 -0.007712
# rho        0.127363  0.200040 -0.146768  0.023278  0.000064  0.023327
# e_rho      1.000000  0.577823  0.577946  0.036712  0.130032 -0.425041
# dHp        0.577823  1.000000  0.117679 -0.007049 -0.025434 -0.256972
# e_dHp      0.577946  0.117679  1.000000  0.017627  0.105853 -0.420521
# HD         0.036712 -0.007049  0.017627  1.000000  0.042434  0.010415
# (V-I)red   0.130032 -0.025434  0.105853  0.042434  1.000000  0.165294
# Target    -0.425041 -0.256972 -0.420521  0.010415  0.165294  1.000000

# %%
df[objCols]
# Out:
#       Proxy        RAhms        DEdms r_Vmag AstroRef m_BTmag r_B-V r_V-I  \
# 0       NaN  00 00 00.91  -19 29 55.8      G        +     NaN     G     I
# 1       NaN  00 00 01.20  +38 51 33.4      G      NaN     NaN     G     H
# 2       NaN  00 00 05.41  +20 02 11.8      G      NaN     NaN     G     H
# 3       NaN  00 00 06.55  +25 53 11.3      H      NaN     NaN     T     O
# 4       NaN  00 00 08.48  +36 35 09.4      H      NaN     NaN     T     L
# ...     ...          ...          ...    ...      ...     ...   ...   ...
# 71617   NaN  23 59 49.40  +21 08 59.1      H      NaN     NaN     G     H
# 71618   NaN  23 59 49.64  -37 51 28.6      H      NaN     NaN     T     L
# 71619   NaN  23 59 51.30  +11 40 25.4      H      NaN     NaN     T     L
# 71620   NaN  23 59 53.74  -22 25 41.4      G      NaN     NaN     G     H
# 71621   NaN  23 59 54.25  +05 57 23.9      H      NaN     NaN     T     L
#
#       CombMag m_Hpmag HvarType        CCDM n_CCDM MultFlag Qual m_HIP Survey  \
# 0         NaN     NaN        C         NaN    NaN        O  NaN   NaN    NaN
# 1         NaN     NaN        C  00000+3852      I      NaN  NaN   NaN      S
# 2         NaN     NaN        C         NaN    NaN      NaN  NaN   NaN    NaN
# 3         NaN     NaN        V         NaN    NaN      NaN    S   NaN    NaN
# 4         NaN     NaN        C         NaN    NaN      NaN  NaN   NaN    NaN
# ...       ...     ...      ...         ...    ...      ...  ...   ...    ...
# 71617     NaN     NaN        C         NaN    NaN      NaN  NaN   NaN    NaN
# 71618     NaN     NaN        C         NaN    NaN      NaN  NaN   NaN    NaN
# 71619     NaN     NaN        V         NaN    NaN      NaN  NaN   NaN      S
# 71620     NaN     NaN        C         NaN    NaN      NaN  NaN   NaN      S
# 71621     NaN     NaN        C         NaN    NaN      NaN  NaN   NaN      S
#
#       Chart Notes         BD         CoD         CPD        SpType r_SpType
# 0       NaN   NaN  B-20 6688         NaN         NaN           K3V        4
# 1       NaN   NaN  B+38 5108         NaN         NaN            B9        S
# 2       NaN   NaN  B+19 5185         NaN         NaN            G0        S
# 3         G     P  B+25 5054         NaN         NaN  M6e-M8.5e Tc        G
# 4       NaN   NaN  B+35 5149         NaN         NaN            G5        S
# ...     ...   ...        ...         ...         ...           ...      ...
# 71617   NaN   NaN  B+20 5413         NaN         NaN            F0        S
# 71618   NaN   NaN        NaN  C-38 15704  P-38  8593            K0        S
# 71619   NaN   NaN  B+10 5018         NaN         NaN            K2        S
# 71620   NaN   NaN        NaN  C-23 18108  P-23  8366           G2V        4
# 71621   NaN   NaN  B+05 5245         NaN         NaN            K0        S
#
# [71622 rows x 24 columns]

# %%
df[numCols]
# Out:
#           HIP  Vmag       RAdeg      DEdeg    Plx    pmRA    pmDE  e_RAdeg  \
# 0           2  9.27    0.003797 -19.498837  21.90  181.21   -0.93     1.28
# 1           3  6.61    0.005008  38.859286   2.81    5.24   -2.91     0.53
# 2           7  9.64    0.022549  20.036602  17.74 -208.12 -200.79     1.01
# 3           8  9.05    0.027292  25.886474   5.17   19.09   -5.66     1.70
# 4           9  8.59    0.035342  36.585938   4.81   -6.30    8.42     0.86
# ...       ...   ...         ...        ...    ...     ...     ...      ...
# 71617  118313  8.94  359.955817  21.149740   2.32    0.28  -15.77     0.89
# 71618  118314  9.27  359.956824 -37.857956   0.93   -6.60   -4.60     1.03
# 71619  118318  6.99  359.963744  11.673709   1.92   -2.16    2.09     0.78
# 71620  118319  8.23  359.973913 -22.428180  10.63  148.74   27.53     0.97
# 71621  118320  7.59  359.976057   5.956638   5.00   20.92  -35.26     0.95
#
#        e_DEdeg  e_Plx  e_pmRA  e_pmDE  DE:RA  Plx:RA  Plx:DE  pmRA:RA  \
# 0         0.70   3.10    1.74    0.92   0.12   -0.14   -0.24    -0.29
# 1         0.40   0.63    0.57    0.47   0.06    0.09    0.04     0.43
# 2         0.79   1.30    1.13    0.82   0.32    0.08   -0.02    -0.04
# 3         0.93   1.95    1.54    0.88   0.27   -0.66   -0.36    -0.38
# 4         0.55   0.99    1.02    0.65   0.03    0.16   -0.01     0.00
# ...        ...    ...     ...     ...    ...     ...     ...      ...
# 71617     0.70   1.15    0.90    0.70   0.28    0.21    0.03     0.02
# 71618     0.76   1.32    1.35    0.85   0.11   -0.10   -0.05    -0.21
# 71619     0.50   0.91    0.88    0.60   0.33   -0.02   -0.09    -0.19
# 71620     0.58   1.17    1.10    0.52   0.04    0.17    0.04    -0.11
# 71621     0.53   1.01    0.89    0.54   0.21    0.00   -0.05    -0.18
#
#        pmRA:DE  pmRA:Plx  pmDE:RA  pmDE:DE  pmDE:Plx  pmDE:pmRA   F1    F2  \
# 0         0.01      0.21    -0.02    -0.19     -0.28       0.14  2.0  1.45
# 1        -0.01     -0.06     0.03     0.24      0.07       0.21  0.0 -0.45
# 2         0.12      0.06     0.11     0.00      0.16       0.43  0.0  0.21
# 3        -0.12      0.36    -0.21    -0.24      0.32       0.18  0.0  0.98
# 4         0.07     -0.02     0.08     0.04      0.10       0.13  3.0 -1.26
# ...        ...       ...      ...      ...       ...        ...  ...   ...
# 71617    -0.03      0.06     0.03    -0.25      0.30       0.27  0.0  1.21
# 71618    -0.03      0.23    -0.06    -0.38      0.00      -0.13  0.0  0.26
# 71619    -0.03      0.21    -0.02    -0.11      0.27       0.49  0.0  2.00
# 71620     0.10      0.17     0.07    -0.31      0.12      -0.05  0.0  1.19
# 71621     0.01     -0.04     0.01    -0.14      0.22       0.27  4.0 -1.12
#
#         BTmag  e_BTmag  VTmag  e_VTmag    B-V  e_B-V   V-I  e_V-I   Hpmag  \
# 0      10.519    0.033  9.378    0.021  0.999  0.002  1.04   0.00  9.4017
# 1       6.576    0.004  6.621    0.005 -0.019  0.004  0.00   0.00  6.6081
# 2      10.542    0.039  9.679    0.030  0.740  0.020  0.79   0.02  9.6795
# 3      10.433    0.055  9.151    0.029  1.102  0.051  3.92   0.39  8.5522
# 4       9.962    0.025  8.711    0.015  1.067  0.023  1.03   0.02  8.7534
# ...       ...      ...    ...      ...    ...    ...   ...    ...     ...
# 71617   9.400    0.019  8.989    0.019  0.423  0.015  0.49   0.02  9.0336
# 71618  10.731    0.034  9.378    0.018  1.147  0.030  1.11   0.03  9.4350
# 71619   9.107    0.015  7.186    0.007  1.595  0.013  1.61   0.01  7.1043
# 71620   9.019    0.013  8.295    0.011  0.639  0.015  0.70   0.01  8.3699
# 71621   8.868    0.013  7.704    0.009  0.999  0.012  0.98   0.01  7.7604
#
#        e_Hpmag  Hpscat  o_Hpmag  Hpmax  HPmin  Nsys  Ncomp  theta  rho  e_rho  \
# 0       0.0017   0.015    120.0   9.37   9.44   NaN    1.0    NaN  NaN    NaN
# 1       0.0007   0.008    127.0   6.60   6.62   1.0    1.0    NaN  NaN    NaN
# 2       0.0021   0.017    104.0   9.65   9.72   NaN    1.0    NaN  NaN    NaN
# 3       0.1671   1.460     77.0   7.15  11.25   NaN    1.0    NaN  NaN    NaN
# 4       0.0018   0.014    107.0   8.73   8.78   NaN    1.0    NaN  NaN    NaN
# ...        ...     ...      ...    ...    ...   ...    ...    ...  ...    ...
# 71617   0.0021   0.013     92.0   9.01   9.06   NaN    1.0    NaN  NaN    NaN
# 71618   0.0020   0.022    148.0   9.38   9.47   NaN    1.0    NaN  NaN    NaN
# 71619   0.0018   0.014     92.0   7.08   7.12   NaN    1.0    NaN  NaN    NaN
# 71620   0.0014   0.016    118.0   8.34   8.39   NaN    1.0    NaN  NaN    NaN
# 71621   0.0010   0.010     86.0   7.74   7.77   NaN    1.0    NaN  NaN    NaN
#
#        dHp  e_dHp        HD  (V-I)red  Target
# 0      NaN    NaN  224690.0      1.04       0
# 1      NaN    NaN  224699.0      0.00       0
# 2      NaN    NaN       NaN      0.79       0
# 3      NaN    NaN  224709.0      4.82       1
# 4      NaN    NaN  224708.0      1.00       0
# ...    ...    ...       ...       ...     ...
# 71617  NaN    NaN  224671.0      0.49       0
# 71618  NaN    NaN       NaN      1.03       0
# 71619  NaN    NaN  224673.0      1.56       1
# 71620  NaN    NaN  224693.0      0.70       0
# 71621  NaN    NaN  224689.0      0.98       0
#
# [71622 rows x 48 columns]

# %%
for col in numCols:
    print(col)
    display(df[col].value_counts())
    display(df[col].isna().sum() / len(df))
# Out:
# HIP
# 2047      1
# 80242     1
# 98661     1
# 104806    1
# 117100    1
#          ..
# 44287     1
# 48381     1
# 46332     1
# 34042     1
# 2049      1
# Name: HIP, Length: 71622, dtype: int64
# 0.0
# Vmag
# 8.65     300
# 8.94     299
# 8.27     299
# 8.44     297
# 8.40     294
#         ...
# 13.31      1
# 3.87       1
# 12.86      1
# 1.83       1
# 1.67       1
# Name: Vmag, Length: 1085, dtype: int64
# 0.0
# RAdeg
# 78.810238     1
# 264.453318    1
# 234.687241    1
# 185.236040    1
# 236.429562    1
#              ..
# 153.973253    1
# 263.560900    1
# 230.179443    1
# 276.217470    1
# 110.228839    1
# Name: RAdeg, Length: 71409, dtype: int64
# 0.002973946552735193
# DEdeg
#  58.423605    1
# -60.756959    1
#  9.851969     1
#  41.715546    1
#  41.170547    1
#              ..
#  20.996500    1
#  2.627515     1
# -44.781548    1
# -30.935057    1
#  47.178000    1
# Name: DEdeg, Length: 71409, dtype: int64
# 0.002973946552735193
# Plx
#  2.51     116
#  2.93     115
#  2.92     113
#  2.71     106
#  3.37     106
#          ...
# -6.12       1
#  31.02      1
#  17.73      1
#  29.47      1
#  35.21      1
# Name: Plx, Length: 4755, dtype: int64
# 0.002973946552735193
# pmRA
# -4.42      34
# -2.71      33
# -2.07      32
# -1.48      32
# -2.26      32
#            ..
# -51.24      1
#  69.22      1
# -277.32     1
#  50.52      1
# -77.61      1
# Name: pmRA, Length: 18828, dtype: int64
# 0.002973946552735193
# pmDE
# -1.89      38
# -6.24      36
#  0.13      35
# -0.41      33
# -1.00      33
#            ..
# -192.52     1
#  30.20      1
#  31.55      1
# -126.30     1
# -64.00      1
# Name: pmDE, Length: 17230, dtype: int64
# 0.002973946552735193
# e_RAdeg
# 0.79     866
# 0.74     842
# 0.81     841
# 0.75     837
# 0.87     833
#         ...
# 28.08      1
# 14.21      1
# 9.22       1
# 38.45      1
# 31.80      1
# Name: e_RAdeg, Length: 1697, dtype: int64
# 0.002973946552735193
# e_DEdeg
# 0.61     1370
# 0.64     1343
# 0.58     1342
# 0.59     1327
# 0.63     1326
#          ...
# 20.28       1
# 41.66       1
# 66.08       1
# 48.04       1
# 7.90        1
# Name: e_DEdeg, Length: 1533, dtype: int64
# 0.002973946552735193
# e_Plx
# 0.95     829
# 0.92     816
# 1.01     810
# 0.90     809
# 0.96     797
#         ...
# 11.15      1
# 10.59      1
# 15.05      1
# 19.70      1
# 7.93       1
# Name: e_Plx, Length: 1264, dtype: int64
# 0.002973946552735193
# e_pmRA
# 0.79     719
# 0.92     691
# 0.88     690
# 0.85     685
# 0.90     676
#         ...
# 33.74      1
# 34.80      1
# 53.03      1
# 24.72      1
# 14.38      1
# Name: e_pmRA, Length: 1440, dtype: int64
# 0.002973946552735193
# e_pmDE
# 0.76     1084
# 0.73     1046
# 0.72     1035
# 0.74     1033
# 0.71     1013
#          ...
# 40.51       1
# 24.37       1
# 13.95       1
# 9.84        1
# 13.80       1
# Name: e_pmDE, Length: 1295, dtype: int64
# 0.002973946552735193
# DE:RA
#  0.00    1440
# -0.01    1430
# -0.02    1407
#  0.01    1407
# -0.03    1405
#          ...
# -0.82       1
# -0.77       1
#  0.96       1
# -0.98       1
# -0.88       1
# Name: DE:RA, Length: 176, dtype: int64
# 0.002973946552735193
# Plx:RA
# -0.01    1495
#  0.00    1458
#  0.04    1423
#  0.02    1399
#  0.01    1381
#          ...
#  0.99       1
#  0.76       1
# -0.71       1
# -0.94       1
# -0.82       1
# Name: Plx:RA, Length: 169, dtype: int64
# 0.002973946552735193
# Plx:DE
# -0.11    1876
# -0.09    1856
# -0.06    1821
# -0.07    1819
# -0.10    1804
#          ...
#  0.56       1
#  0.64       1
# -0.70       1
#  0.52       1
#  0.84       1
# Name: Plx:DE, Length: 136, dtype: int64
# 0.002973946552735193
# pmRA:RA
#  0.04    1447
#  0.00    1436
#  0.01    1426
#  0.06    1416
#  0.05    1413
#          ...
#  0.88       1
# -0.83       1
#  0.76       1
# -0.94       1
#  0.83       1
# Name: pmRA:RA, Length: 177, dtype: int64
# 0.002973946552735193
# pmRA:DE
#  0.00    2104
#  0.02    2063
# -0.01    2050
# -0.03    2021
#  0.04    2006
#          ...
# -0.87       1
#  0.73       1
# -0.82       1
# -0.68       1
# -0.75       1
# Name: pmRA:DE, Length: 154, dtype: int64
# 0.002973946552735193
# pmRA:Plx
# -0.01    1990
# -0.03    1914
#  0.03    1910
#  0.01    1900
# -0.02    1838
#          ...
# -0.72       1
# -0.61       1
#  0.76       1
# -0.68       1
# -0.60       1
# Name: pmRA:Plx, Length: 142, dtype: int64
# 0.002973946552735193
# pmDE:RA
#  0.00    2197
#  0.02    2147
#  0.04    2128
#  0.03    2099
# -0.01    2088
#          ...
# -0.67       1
#  0.69       1
# -0.94       1
#  0.72       1
# -0.72       1
# Name: pmDE:RA, Length: 155, dtype: int64
# 0.002973946552735193
# pmDE:DE
# -0.08    1150
#  0.03    1141
# -0.06    1137
# -0.05    1137
# -0.04    1134
#          ...
# -0.98       1
# -0.95       1
#  0.85       1
# -0.92       1
# -0.94       1
# Name: pmDE:DE, Length: 187, dtype: int64
# 0.002973946552735193
# pmDE:Plx
#  0.06    1896
#  0.05    1892
#  0.00    1808
#  0.04    1791
#  0.03    1788
#          ...
#  0.70       1
# -0.63       1
# -0.61       1
#  0.67       1
#  0.94       1
# Name: pmDE:Plx, Length: 135, dtype: int64
# 0.002973946552735193
# pmDE:pmRA
#  0.00    1159
# -0.02    1151
# -0.05    1123
# -0.03    1123
# -0.01    1105
#          ...
# -0.82       1
#  0.87       1
#  0.93       1
#  0.94       1
#  0.88       1
# Name: pmDE:pmRA, Length: 177, dtype: int64
# 0.002973946552735193
# F1
# 0.0     48668
# 1.0      8225
# 2.0      7229
# 3.0      2993
# 4.0      1637
# 5.0       815
# 6.0       412
# 7.0       255
# 8.0       160
# 9.0       146
# 10.0      107
# 17.0       86
# 11.0       85
# 18.0       84
# 12.0       78
# 16.0       78
# 13.0       70
# 15.0       67
# 14.0       56
# 19.0       43
# 21.0       20
# 20.0       13
# 23.0       12
# 36.0        8
# 22.0        7
# 24.0        6
# 25.0        6
# 31.0        6
# 26.0        6
# 38.0        5
# 40.0        4
# 28.0        4
# 34.0        3
# 35.0        3
# 29.0        3
# 33.0        3
# 37.0        3
# 30.0        1
# 47.0        1
# 44.0        1
# Name: F1, dtype: int64
# 0.002973946552735193
# F2
# -0.05     315
#  0.07     312
#  0.30     300
#  0.42     298
#  0.20     292
#          ...
#  4.61       1
#  9.56       1
#  5.09       1
#  12.48      1
#  3.89       1
# Name: F2, Length: 834, dtype: int64
# 0.01535840942727095
# BTmag
# 9.531     40
# 9.710     39
# 9.083     39
# 10.068    39
# 9.996     38
#           ..
# 4.611      1
# 6.575      1
# 5.949      1
# 5.974      1
# 4.817      1
# Name: BTmag, Length: 7581, dtype: int64
# 0.025480997458881348
# e_BTmag
# 0.010    3004
# 0.011    2963
# 0.012    2915
# 0.009    2867
# 0.013    2720
#          ...
# 0.394       1
# 1.378       1
# 0.375       1
# 0.325       1
# 0.285       1
# Name: e_BTmag, Length: 381, dtype: int64
# 0.025480997458881348
# VTmag
# 8.545    47
# 9.151    46
# 8.958    45
# 8.926    44
# 8.879    43
#          ..
# 5.121     1
# 3.857     1
# 4.881     1
# 5.059     1
# 3.301     1
# Name: VTmag, Length: 6791, dtype: int64
# 0.02496439641450951
# e_VTmag
# 0.009    3811
# 0.010    3791
# 0.011    3667
# 0.012    3529
# 0.008    3414
#          ...
# 0.191       1
# 0.211       1
# 0.173       1
# 0.170       1
# 0.248       1
# Name: e_VTmag, Length: 203, dtype: int64
# 0.02496439641450951
# B-V
# 1.000    216
# 0.500    203
# 1.500    192
# 0.600    180
# 0.400    169
#         ...
# 2.835      1
# 1.875      1
# 1.967      1
# 2.106      1
# 2.065      1
# Name: B-V, Length: 2375, dtype: int64
# 0.012719555443858032
# e_B-V
# 0.015    10878
# 0.020     3338
# 0.010     2039
# 0.013     1972
# 0.012     1964
#          ...
# 0.179        1
# 0.302        1
# 0.293        1
# 0.222        1
# 0.181        1
# Name: e_B-V, Length: 277, dtype: int64
# 0.012719555443858032
# V-I
# 0.58    893
# 0.55    853
# 0.57    830
# 0.52    828
# 0.62    798
#        ...
# 3.13      1
# 5.04      1
# 4.09      1
# 3.73      1
# 4.73      1
# Name: V-I, Length: 510, dtype: int64
# 0.012719555443858032
# e_V-I
# 0.01    22450
# 0.02    19961
# 0.03     8642
# 0.00     5517
# 0.04     4986
#         ...
# 1.33        1
# 1.18        1
# 1.22        1
# 2.45        1
# 0.63        1
# Name: e_V-I, Length: 109, dtype: int64
# 0.012719555443858032
# Hpmag
# 8.8639     10
# 8.4278     10
# 9.0273     10
# 8.6533     10
# 8.9519     10
#            ..
# 10.0854     1
# 7.4277      1
# 7.0823      1
# 7.3429      1
# 8.0000      1
# Name: Hpmag, Length: 37352, dtype: int64
# 1.3962190388428136e-05
# e_Hpmag
# 0.0015    3526
# 0.0016    3455
# 0.0014    3451
# 0.0013    3442
# 0.0017    3373
#           ...
# 0.1184       1
# 0.1458       1
# 0.0699       1
# 0.1313       1
# 0.0625       1
# Name: e_Hpmag, Length: 1224, dtype: int64
# 1.3962190388428136e-05
# Hpscat
# 0.014    4409
# 0.013    4185
# 0.015    4086
# 0.012    4037
# 0.016    3893
#          ...
# 0.671       1
# 0.511       1
# 0.756       1
# 1.873       1
# 1.205       1
# Name: Hpscat, Length: 768, dtype: int64
# 0.013194269917064589
# o_Hpmag
# 80.0     977
# 82.0     953
# 81.0     933
# 77.0     915
# 78.0     909
#         ...
# 9.0        1
# 20.0       1
# 28.0       1
# 338.0      1
# 26.0       1
# Name: o_Hpmag, Length: 302, dtype: int64
# 0.013194269917064589
# Hpmax
# 8.54     291
# 8.45     287
# 8.87     283
# 8.74     281
# 8.77     277
#         ...
# 1.69       1
# 3.63       1
# 1.96       1
# 12.12      1
# 1.50       1
# Name: Hpmax, Length: 1030, dtype: int64
# 0.013194269917064589
# HPmin
# 8.63    290
# 8.58    286
# 8.60    282
# 8.75    276
# 8.94    276
#        ...
# 3.95      1
# 3.72      1
# 3.58      1
# 3.90      1
# 2.91      1
# Name: HPmin, Length: 1098, dtype: int64
# 0.013194269917064589
# Nsys
# 1.0    12546
# 2.0     3071
# 3.0      106
# 4.0       13
# Name: Nsys, dtype: int64
# 0.7802909720476948
# Ncomp
# 1.0    61431
# 2.0     9844
# 3.0      128
# 4.0        6
# Name: Ncomp, dtype: int64
# 0.002973946552735193
# theta
# 4.0      47
# 0.0      43
# 26.0     42
# 270.0    42
# 191.0    41
#          ..
# 34.0     17
# 151.0    16
# 224.0    15
# 230.0    15
# 206.0    15
# Name: theta, Length: 360, dtype: int64
# 0.8625561978163134
# rho
# 0.142    20
# 0.135    20
# 0.234    19
# 0.177    17
# 0.187    17
#          ..
# 6.368     1
# 7.818     1
# 2.585     1
# 4.266     1
# 5.545     1
# Name: rho, Length: 4356, dtype: int64
# 0.8625561978163134
# e_rho
# 0.004    855
# 0.005    814
# 0.003    741
# 0.006    687
# 0.007    535
#         ...
# 0.202      1
# 0.141      1
# 0.191      1
# 0.242      1
# 0.127      1
# Name: e_rho, Length: 139, dtype: int64
# 0.8625561978163134
# dHp
# 0.13    66
# 0.05    61
# 0.10    57
# 0.23    55
# 0.17    54
#         ..
# 4.47     1
# 4.22     1
# 4.28     1
# 4.34     1
# 4.24     1
# Name: dHp, Length: 432, dtype: int64
# 0.8625561978163134
# e_dHp
# 0.02    1611
# 0.01    1016
# 0.03     962
# 0.04     699
# 0.05     565
#         ...
# 4.61       1
# 1.54       1
# 1.26       1
# 1.71       1
# 2.57       1
# Name: e_dHp, Length: 160, dtype: int64
# 0.8625561978163134
# HD
# 22878.0     2
# 141186.0    2
# 196197.0    2
# 126049.0    2
# 76323.0     2
#            ..
# 125503.0    1
# 49969.0     1
# 38175.0     1
# 185467.0    1
# 1.0         1
# Name: HD, Length: 60003, dtype: int64
# 0.16144480746139456
# (V-I)red
# 0.64    976
# 0.65    958
# 0.58    922
# 0.57    907
# 0.98    862
#        ...
# 6.99      1
# 3.94      1
# 6.10      1
# 4.09      1
# 3.89      1
# Name: (V-I)red, Length: 559, dtype: int64
# 0.0
# Target
# 0    46552
# 1    25070
# Name: Target, dtype: int64
# 0.0

# %%
df[df['theta'].isna()]['rho'].isna().sum()
# Out:
# 61778

# %%
df['r_SpType'].value_counts()
# Out:
# S    35184
# X     8494
# 3     6436
# 1     6403
# 4     6226
# 2     5279
# G     1132
# K      653
# Name: r_SpType, dtype: int64

# %%
df
# Out:
#           HIP Proxy        RAhms        DEdms  Vmag r_Vmag       RAdeg  \
# 0           2   NaN  00 00 00.91  -19 29 55.8  9.27      G    0.003797
# 1           3   NaN  00 00 01.20  +38 51 33.4  6.61      G    0.005008
# 2           7   NaN  00 00 05.41  +20 02 11.8  9.64      G    0.022549
# 3           8   NaN  00 00 06.55  +25 53 11.3  9.05      H    0.027292
# 4           9   NaN  00 00 08.48  +36 35 09.4  8.59      H    0.035342
# ...       ...   ...          ...          ...   ...    ...         ...
# 71617  118313   NaN  23 59 49.40  +21 08 59.1  8.94      H  359.955817
# 71618  118314   NaN  23 59 49.64  -37 51 28.6  9.27      H  359.956824
# 71619  118318   NaN  23 59 51.30  +11 40 25.4  6.99      H  359.963744
# 71620  118319   NaN  23 59 53.74  -22 25 41.4  8.23      G  359.973913
# 71621  118320   NaN  23 59 54.25  +05 57 23.9  7.59      H  359.976057
#
#            DEdeg AstroRef    Plx    pmRA    pmDE  e_RAdeg  e_DEdeg  e_Plx  \
# 0     -19.498837        +  21.90  181.21   -0.93     1.28     0.70   3.10
# 1      38.859286      NaN   2.81    5.24   -2.91     0.53     0.40   0.63
# 2      20.036602      NaN  17.74 -208.12 -200.79     1.01     0.79   1.30
# 3      25.886474      NaN   5.17   19.09   -5.66     1.70     0.93   1.95
# 4      36.585938      NaN   4.81   -6.30    8.42     0.86     0.55   0.99
# ...          ...      ...    ...     ...     ...      ...      ...    ...
# 71617  21.149740      NaN   2.32    0.28  -15.77     0.89     0.70   1.15
# 71618 -37.857956      NaN   0.93   -6.60   -4.60     1.03     0.76   1.32
# 71619  11.673709      NaN   1.92   -2.16    2.09     0.78     0.50   0.91
# 71620 -22.428180      NaN  10.63  148.74   27.53     0.97     0.58   1.17
# 71621   5.956638      NaN   5.00   20.92  -35.26     0.95     0.53   1.01
#
#        e_pmRA  e_pmDE  DE:RA  Plx:RA  Plx:DE  pmRA:RA  pmRA:DE  pmRA:Plx  \
# 0        1.74    0.92   0.12   -0.14   -0.24    -0.29     0.01      0.21
# 1        0.57    0.47   0.06    0.09    0.04     0.43    -0.01     -0.06
# 2        1.13    0.82   0.32    0.08   -0.02    -0.04     0.12      0.06
# 3        1.54    0.88   0.27   -0.66   -0.36    -0.38    -0.12      0.36
# 4        1.02    0.65   0.03    0.16   -0.01     0.00     0.07     -0.02
# ...       ...     ...    ...     ...     ...      ...      ...       ...
# 71617    0.90    0.70   0.28    0.21    0.03     0.02    -0.03      0.06
# 71618    1.35    0.85   0.11   -0.10   -0.05    -0.21    -0.03      0.23
# 71619    0.88    0.60   0.33   -0.02   -0.09    -0.19    -0.03      0.21
# 71620    1.10    0.52   0.04    0.17    0.04    -0.11     0.10      0.17
# 71621    0.89    0.54   0.21    0.00   -0.05    -0.18     0.01     -0.04
#
#        pmDE:RA  pmDE:DE  pmDE:Plx  pmDE:pmRA   F1    F2   BTmag  e_BTmag  \
# 0        -0.02    -0.19     -0.28       0.14  2.0  1.45  10.519    0.033
# 1         0.03     0.24      0.07       0.21  0.0 -0.45   6.576    0.004
# 2         0.11     0.00      0.16       0.43  0.0  0.21  10.542    0.039
# 3        -0.21    -0.24      0.32       0.18  0.0  0.98  10.433    0.055
# 4         0.08     0.04      0.10       0.13  3.0 -1.26   9.962    0.025
# ...        ...      ...       ...        ...  ...   ...     ...      ...
# 71617     0.03    -0.25      0.30       0.27  0.0  1.21   9.400    0.019
# 71618    -0.06    -0.38      0.00      -0.13  0.0  0.26  10.731    0.034
# 71619    -0.02    -0.11      0.27       0.49  0.0  2.00   9.107    0.015
# 71620     0.07    -0.31      0.12      -0.05  0.0  1.19   9.019    0.013
# 71621     0.01    -0.14      0.22       0.27  4.0 -1.12   8.868    0.013
#
#        VTmag  e_VTmag m_BTmag    B-V  e_B-V r_B-V   V-I  e_V-I r_V-I CombMag  \
# 0      9.378    0.021     NaN  0.999  0.002     G  1.04   0.00     I     NaN
# 1      6.621    0.005     NaN -0.019  0.004     G  0.00   0.00     H     NaN
# 2      9.679    0.030     NaN  0.740  0.020     G  0.79   0.02     H     NaN
# 3      9.151    0.029     NaN  1.102  0.051     T  3.92   0.39     O     NaN
# 4      8.711    0.015     NaN  1.067  0.023     T  1.03   0.02     L     NaN
# ...      ...      ...     ...    ...    ...   ...   ...    ...   ...     ...
# 71617  8.989    0.019     NaN  0.423  0.015     G  0.49   0.02     H     NaN
# 71618  9.378    0.018     NaN  1.147  0.030     T  1.11   0.03     L     NaN
# 71619  7.186    0.007     NaN  1.595  0.013     T  1.61   0.01     L     NaN
# 71620  8.295    0.011     NaN  0.639  0.015     G  0.70   0.01     H     NaN
# 71621  7.704    0.009     NaN  0.999  0.012     T  0.98   0.01     L     NaN
#
#         Hpmag  e_Hpmag  Hpscat  o_Hpmag m_Hpmag  Hpmax  HPmin HvarType  \
# 0      9.4017   0.0017   0.015    120.0     NaN   9.37   9.44        C
# 1      6.6081   0.0007   0.008    127.0     NaN   6.60   6.62        C
# 2      9.6795   0.0021   0.017    104.0     NaN   9.65   9.72        C
# 3      8.5522   0.1671   1.460     77.0     NaN   7.15  11.25        V
# 4      8.7534   0.0018   0.014    107.0     NaN   8.73   8.78        C
# ...       ...      ...     ...      ...     ...    ...    ...      ...
# 71617  9.0336   0.0021   0.013     92.0     NaN   9.01   9.06        C
# 71618  9.4350   0.0020   0.022    148.0     NaN   9.38   9.47        C
# 71619  7.1043   0.0018   0.014     92.0     NaN   7.08   7.12        V
# 71620  8.3699   0.0014   0.016    118.0     NaN   8.34   8.39        C
# 71621  7.7604   0.0010   0.010     86.0     NaN   7.74   7.77        C
#
#              CCDM n_CCDM  Nsys  Ncomp MultFlag Qual m_HIP  theta  rho  e_rho  \
# 0             NaN    NaN   NaN    1.0        O  NaN   NaN    NaN  NaN    NaN
# 1      00000+3852      I   1.0    1.0      NaN  NaN   NaN    NaN  NaN    NaN
# 2             NaN    NaN   NaN    1.0      NaN  NaN   NaN    NaN  NaN    NaN
# 3             NaN    NaN   NaN    1.0      NaN    S   NaN    NaN  NaN    NaN
# 4             NaN    NaN   NaN    1.0      NaN  NaN   NaN    NaN  NaN    NaN
# ...           ...    ...   ...    ...      ...  ...   ...    ...  ...    ...
# 71617         NaN    NaN   NaN    1.0      NaN  NaN   NaN    NaN  NaN    NaN
# 71618         NaN    NaN   NaN    1.0      NaN  NaN   NaN    NaN  NaN    NaN
# 71619         NaN    NaN   NaN    1.0      NaN  NaN   NaN    NaN  NaN    NaN
# 71620         NaN    NaN   NaN    1.0      NaN  NaN   NaN    NaN  NaN    NaN
# 71621         NaN    NaN   NaN    1.0      NaN  NaN   NaN    NaN  NaN    NaN
#
#        dHp  e_dHp Survey Chart Notes        HD         BD         CoD  \
# 0      NaN    NaN    NaN   NaN   NaN  224690.0  B-20 6688         NaN
# 1      NaN    NaN      S   NaN   NaN  224699.0  B+38 5108         NaN
# 2      NaN    NaN    NaN   NaN   NaN       NaN  B+19 5185         NaN
# 3      NaN    NaN    NaN     G     P  224709.0  B+25 5054         NaN
# 4      NaN    NaN    NaN   NaN   NaN  224708.0  B+35 5149         NaN
# ...    ...    ...    ...   ...   ...       ...        ...         ...
# 71617  NaN    NaN    NaN   NaN   NaN  224671.0  B+20 5413         NaN
# 71618  NaN    NaN    NaN   NaN   NaN       NaN        NaN  C-38 15704
# 71619  NaN    NaN      S   NaN   NaN  224673.0  B+10 5018         NaN
# 71620  NaN    NaN      S   NaN   NaN  224693.0        NaN  C-23 18108
# 71621  NaN    NaN      S   NaN   NaN  224689.0  B+05 5245         NaN
#
#               CPD  (V-I)red        SpType r_SpType  Target
# 0             NaN      1.04           K3V        4       0
# 1             NaN      0.00            B9        S       0
# 2             NaN      0.79            G0        S       0
# 3             NaN      4.82  M6e-M8.5e Tc        G       1
# 4             NaN      1.00            G5        S       0
# ...           ...       ...           ...      ...     ...
# 71617         NaN      0.49            F0        S       0
# 71618  P-38  8593      1.03            K0        S       0
# 71619         NaN      1.56            K2        S       1
# 71620  P-23  8366      0.70           G2V        4       0
# 71621         NaN      0.98            K0        S       0
#
# [71622 rows x 72 columns]

# %%
for col in df.columns:
    if 'T' in df[col].value_counts().index:
        print(col)
# Out:
# Proxy
# r_Vmag
# r_B-V
# r_V-I

# %%
mode_cols = ['r_B-V','r_V-I','r_Vmag']
mode_imp = Pipeline(steps=[
    ('mode_imp', SimpleImputer(strategy='most_frequent')),
    ('mode_enc', OneHotEncoder(handle_unknown='ignore'))
])

const_cols = ['AstroRef','m_BTmag','CombMag','Proxy','m_Hpmag','CCDM','n_CCDM','MultFlag','Qual','Survey',
              'Chart','Notes','r_SpType']
const_imp = Pipeline(steps=[
    ('const_imp', SimpleImputer(strategy='constant',fill_value='Null')),
    ('const_enc', OneHotEncoder(handle_unknown='ignore'))
])

num_cols = ['Vmag', "RAdeg", 'DEdeg', 'Plx', 'pmRA', 'pmDE', 'e_RAdeg', 'e_DEdeg', 'e_Plx', 'e_pmRA',
           'e_pmDE', 'DE:RA', 'Plx:RA', 'Plx:DE', 'pmRA:RA', 'pmRA:DE', 'pmRA:Plx', 'pmDE:RA', 'pmDE:DE',
           'pmDE:Plx', 'pmDE:pmRA', 'F1', 'F2', 'BTmag', 'VTmag', 'e_VTmag', 'B-V', 'e_B-V', 'V-I', 'e_V-I',
           'Hpmag', 'e_Hpmag', 'Hpscat', 'o_Hpmag', 'Hpmax', 'HPmin', 'rho', 'e_rho', 'dHp', 'e_dHp', '(V-I)red']
num_imp = Pipeline(steps=[
    ('num_imp',SimpleImputer(strategy='mean'))
])

missing_ind_cols = ['theta']
missing_ind_imp = Pipeline(steps=[
    ('missing_ind_imp', SimpleImputer(strategy='mean', add_indicator=True))
])

num_const_cols = ['Nsys', 'Ncomp']
num_const_imp = Pipeline(steps=[
    ('num_const_imp', SimpleImputer(strategy='constant', fill_value=1.0))
])

use_cols = [
#     *mode_cols,
#     *const_cols,
    *num_cols, 
#     *missing_ind_cols, 
    *num_const_cols
]

# %%
preprocessor = ColumnTransformer(transformers=[
#     ('mode_pre', mode_imp, mode_cols),
#     ('const_pre', const_imp, const_cols),
    ('num_pre', num_imp, num_cols),
#     ('missing_ind_pre', missing_ind_imp, missing_ind_cols),
    ('num_const_pre', num_const_imp, num_const_cols)
])

# %%
# tree = Pipeline(steps=[
#     ('preprocessor',preprocessor),
# #     ('scaler'`, StandardScaler(with_mean=False)),
#     ('tree', DecisionTreeClassifier(random_state=42, max_depth=50, min_samples_split=100))
# ])
x_tr_pro = preprocessor.fit_transform(x_train[use_cols])
tree = DecisionTreeClassifier(random_state=42, max_depth=50, min_samples_split=100)

selector = RFE(tree, n_features_to_select=3, step=1)
selector.fit(x_tr_pro, y_train)

ranking = selector.ranking_

# param_grid = {
#     "tree__max_depth" : [1, 10, 50, 100],
#     "tree__min_samples_split" : [None, 5, 10, 50, 100],
# }
# cv_rfc = GridSearchCV(estimator=tree, param_grid=param_grid, cv=5)
# cv_rfc.fit(x_train[use_cols], y_train)

# print(cv_rfc.best_score_)

# estimator = cv_rfc.best_estimator_
# print(estimator)
# displayMetrics(estimator, x_train[use_cols], x_test[use_cols], y_train, y_test)

# %%
ranking
# Out:
# array([16, 21, 18, 19, 34, 23, 24,  8, 17, 31, 20, 37, 25, 22, 29, 30, 33,
#        35, 40, 28, 38, 32, 15, 10,  5,  4,  2, 13, 26, 39,  7,  3,  1, 11,
#         1, 36, 41,  9, 27, 12, 14,  6,  1])

# %%
# mode_pre_col = preprocessor.named_transformers_["mode_pre"].get_feature_names()
# const_pre_col = preprocessor.named_transformers_["const_pre"].get_feature_names()

grand_col = [
#     *mode_pre_col, 
#     *const_pre_col, 
    *num_cols, 
#     *missing_ind_cols, 
    *num_const_cols
]

# %%
grand_col
# Out:
# ['Vmag',
#  'RAdeg',
#  'DEdeg',
#  'Plx',
#  'pmRA',
#  'pmDE',
#  'e_RAdeg',
#  'e_DEdeg',
#  'e_Plx',
#  'e_pmRA',
#  'e_pmDE',
#  'DE:RA',
#  'Plx:RA',
#  'Plx:DE',
#  'pmRA:RA',
#  'pmRA:DE',
#  'pmRA:Plx',
#  'pmDE:RA',
#  'pmDE:DE',
#  'pmDE:Plx',
#  'pmDE:pmRA',
#  'F1',
#  'F2',
#  'BTmag',
#  'VTmag',
#  'e_VTmag',
#  'B-V',
#  'e_B-V',
#  'V-I',
#  'e_V-I',
#  'Hpmag',
#  'e_Hpmag',
#  'Hpscat',
#  'o_Hpmag',
#  'Hpmax',
#  'HPmin',
#  'rho',
#  'e_rho',
#  'dHp',
#  'e_dHp',
#  '(V-I)red',
#  'Nsys',
#  'Ncomp']

# %%
# grand_obj = dict(zip(grand_col, ranking))

# %%
grand_num = dict(zip(grand_col, ranking))

# %%
grand_num
# Out:
# {'Vmag': 16,
#  'RAdeg': 21,
#  'DEdeg': 18,
#  'Plx': 19,
#  'pmRA': 34,
#  'pmDE': 23,
#  'e_RAdeg': 24,
#  'e_DEdeg': 8,
#  'e_Plx': 17,
#  'e_pmRA': 31,
#  'e_pmDE': 20,
#  'DE:RA': 37,
#  'Plx:RA': 25,
#  'Plx:DE': 22,
#  'pmRA:RA': 29,
#  'pmRA:DE': 30,
#  'pmRA:Plx': 33,
#  'pmDE:RA': 35,
#  'pmDE:DE': 40,
#  'pmDE:Plx': 28,
#  'pmDE:pmRA': 38,
#  'F1': 32,
#  'F2': 15,
#  'BTmag': 10,
#  'VTmag': 5,
#  'e_VTmag': 4,
#  'B-V': 2,
#  'e_B-V': 13,
#  'V-I': 26,
#  'e_V-I': 39,
#  'Hpmag': 7,
#  'e_Hpmag': 3,
#  'Hpscat': 1,
#  'o_Hpmag': 11,
#  'Hpmax': 1,
#  'HPmin': 36,
#  'rho': 41,
#  'e_rho': 9,
#  'dHp': 27,
#  'e_dHp': 12,
#  '(V-I)red': 14,
#  'Nsys': 6,
#  'Ncomp': 1}

# %%
max(grand_num.values())
final_list = [
    "Ncomp",
    "Hpmax",
    "Nsys",
    "Hpscat",
    "e_Hpmag",
    'B-V',
    'e_VTmag',
    'VTmag'
]
# Out:
# 41

# %%
x = 42
while x > 1:
    x -= 1
    grand_col1 = []
    grand_col1 = [keys for keys in grand_num.keys()]
    
    preprocessor = ColumnTransformer(transformers=[
        ('num_pre', num_imp, num_cols),
        ('num_const_pre', num_const_imp, num_const_cols)
    ])
    
    tree = Pipeline(steps=[
        ('preprocessor',preprocessor),
#       ('scaler', StandardScaler(with_mean=False)),
        ('tree', DecisionTreeClassifier(random_state=42, max_depth=15, min_samples_split=74))
    ])
    
    tree.fit(x_train[grand_col1], y_train)
    train_preds = tree.predict(x_train[grand_col1])
    test_preds = tree.predict(x_test[grand_col1])
    
    train_accuracy = accuracy_score(y_train, train_preds)
    test_accuracy = accuracy_score(y_test, test_preds)
    train_recall = recall_score(y_train, train_preds, zero_division=0)
    test_recall = recall_score(y_test, test_preds, zero_division=0)
    print(x, "train acc", train_accuracy, "test acc", test_accuracy, "train rec", train_recall, "test rec", test_recall)
    
    drop_col = max(grand_num, key=grand_num.get)
    num_cols.remove(drop_col)
    del grand_num[drop_col]
# Out:
# 41 train acc 0.9398317074986968 test acc 0.9236010275885178 train rec 0.8671850037277665 test rec 0.8471074380165289
# 40 train acc 0.9398503239258321 test acc 0.9237127219926282 train rec 0.8668122270742358 test rec 0.8469485060394152
# 39 train acc 0.9398689403529674 test acc 0.923991958002904 train rec 0.8667589732665886 test rec 0.8475842339478703
# 38 train acc 0.9398130910715615 test acc 0.9240478052049592 train rec 0.8656938971136436 test rec 0.8467895740623014
# 37 train acc 0.9398317074986968 test acc 0.9237685691946833 train rec 0.8654808818830546 test rec 0.8459949141767323
# 36 train acc 0.9398503239258321 test acc 0.9238244163967385 train rec 0.8656406433059963 test rec 0.8464717101080738
# 35 train acc 0.9398503239258321 test acc 0.9239361108008489 train rec 0.8656406433059963 test rec 0.8466306420851876
# 34 train acc 0.9398875567801027 test acc 0.9238244163967385 train rec 0.8660666737671744 test rec 0.8467895740623014
# 33 train acc 0.939906173207238 test acc 0.9239361108008489 train rec 0.8662264351901161 test rec 0.8471074380165289
# 32 train acc 0.9398689403529674 test acc 0.9232659443761867 train rec 0.8662264351901161 test rec 0.8456770502225047
# 31 train acc 0.939906173207238 test acc 0.923042555567966 train rec 0.8662796889977633 test rec 0.8458359821996185
# 30 train acc 0.9399434060615087 test acc 0.9235451803864626 train rec 0.8660666737671744 test rec 0.8459949141767323
# 29 train acc 0.939720008935885 test acc 0.9240478052049592 train rec 0.8664927042283523 test rec 0.8477431659249841
# 28 train acc 0.939962022488644 test acc 0.9241594996090696 train rec 0.8671850037277665 test rec 0.8479020979020979
# 27 train acc 0.9396827760816144 test acc 0.9243828884172903 train rec 0.8671317499201193 test rec 0.8490146217418945
# 26 train acc 0.9395710775188026 test acc 0.9243828884172903 train rec 0.867078496112472 test rec 0.8479020979020979
# 25 train acc 0.9395338446645319 test acc 0.9243270412152351 train rec 0.8680903184577697 test rec 0.8486967577876668
# 24 train acc 0.9393662968203143 test acc 0.9247179716296213 train rec 0.8674512727660028 test rec 0.8490146217418945
# 23 train acc 0.9394221461017201 test acc 0.9246621244275662 train rec 0.8662796889977633 test rec 0.8477431659249841
# 22 train acc 0.939347680393179 test acc 0.9248296660337317 train rec 0.8663861966130578 test rec 0.8477431659249841
# 21 train acc 0.93910566684042 test acc 0.9250530548419524 train rec 0.8663329428054106 test rec 0.8486967577876668
# 20 train acc 0.9390684339861494 test acc 0.9254998324583938 train rec 0.8662796889977633 test rec 0.8499682136045772
# 19 train acc 0.9391615161218259 test acc 0.9253322908522283 train rec 0.8660666737671744 test rec 0.8488556897647807
# 18 train acc 0.9391428996946906 test acc 0.9254439852563386 train rec 0.8675045265736501 test rec 0.850127145581691
# 17 train acc 0.9390684339861494 test acc 0.9254998324583938 train rec 0.867930557034828 test rec 0.85092180546726
# 16 train acc 0.9387891875791198 test acc 0.9270077069138836 train rec 0.8669719884971776 test rec 0.8528289891926255
# 15 train acc 0.9385099411720903 test acc 0.9266726237015526 train rec 0.8679838108424752 test rec 0.8552129688493325
# 14 train acc 0.9387705711519845 test acc 0.9264492348933319 train rec 0.8687826179571839 test rec 0.854100445009536
# 13 train acc 0.9386030233077668 test acc 0.9261141516810008 train rec 0.8692086484183619 test rec 0.8548951048951049
# 12 train acc 0.9381748454836548 test acc 0.9270077069138836 train rec 0.8668122270742358 test rec 0.8552129688493325
# 11 train acc 0.937765284086678 test acc 0.9263933876912767 train rec 0.8693684098413037 test rec 0.8564844246662429
# 10 train acc 0.9379886812123017 test acc 0.9270635541159388 train rec 0.8657471509212908 test rec 0.8553719008264463
# 9 train acc 0.9390312011318788 test acc 0.9273986373282699 train rec 0.8727233997230802 test rec 0.8618881118881119
# 8 train acc 0.9381748454836548 test acc 0.9260024572768905 train rec 0.8733624454148472 test rec 0.8630006357279084
# 7 train acc 0.9365552163228833 test acc 0.9271752485200492 train rec 0.8729896687613165 test rec 0.866497139224412
# 6 train acc 0.9361642713530419 test acc 0.9274544845303251 train rec 0.8733624454148472 test rec 0.8676096630642085
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-b37297dd93d4> in <module>
#      27
#      28     drop_col = max(grand_num, key=grand_num.get)
# ---> 29     num_cols.remove(drop_col)
#      30     del grand_num[drop_col]
#
# ValueError: list.remove(x): x not in list
